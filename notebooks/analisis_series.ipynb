# %%
import pandas as pd

#with open(...)

df_series = pd.read_csv("../data/clean/popular_series.csv")

df_series.head(1)
# Out:
#      id  title                        genre_ids  popularity  vote_average
# 0  1622    NaN  ['Drama', 'Mystery', 'Unknown']    274.6784           8.3

# %%
import matplotlib.pyplot as plt
import ast

generos_series = df_series["genre_ids"].str.split(r" \| ").explode().str.strip().value_counts()

plt.figure(figsize=(4, 2))
generos_series.plot(kind="bar")
# Out:
# <Axes: xlabel='genre_ids'>
