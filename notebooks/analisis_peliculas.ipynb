# %%
import pandas as pd

#with open (..) 
df = pd.read_csv("../data/clean/popular_movies.csv") 

df.head(1)
# Out:
#         id    title     genre_ids  popularity  vote_average
# 0  1290821  Shelter  [28, 80, 53]    434.2537         6.957

# %%
import matplotlib.pyplot as plt

generos = df["genre_ids"].value_counts()

plt.figure(figsize=(10,6))
generos.plot(kind="bar")
# Out:
# <Axes: xlabel='genre_ids'>

# %%
import matplotlib.pyplot as plt 
import ast 

df["genre_ids"].apply(ast.literal_eval).explode().value_counts()
# Out:
# genre_ids
# 28       48
# 53       43
# 18       41
# 80       25
# 27       25
# 12       19
# 878      18
# 35       18
# 10749    11
# 16       11
# 10751    11
# 9648     11
# 14       10
# 10402     4
# 10770     3
# 37        2
# 36        2
# 99        2
# 10752     2
# Name: count, dtype: int64
