# %%
# !pip install matplotlib

# %%
import pandas as pd

#with open(...)

df = pd.read_csv("../data/clean/popular_movies.csv")

df.head(1)
# Out:
#         id    title                        genre_ids  popularity  vote_average
# 0  1290821  Shelter  ['Action', 'Crime', 'Thriller']    434.2537         6.957
